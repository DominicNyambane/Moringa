# %%
import pandas as pd
import numpy as np

sample_data=pd.read_csv("C:/Users/JUD_PMMD/OneDrive/Documents/Moringa/Data Analysis/Data/sample_data.csv")

# %%
col_names = ["empty","T-Day","T-Month","T-Year", "Code", "No", "R-Day","R-Month","R-Year",
         "Origin Court", "Origin Code", "Origin No", "Origin Year", "Specific Case Type",
         "Judge 1", "Judge 2", "Judge 3", "Judge 4", "Judge 5", "Judge 6", "Judge 7", 
         "Case coming for", "Case OutCome", "Reason of adjournment", "N-Day","N-Month",
         "N-Year","P-M", "P-F","P-Org.", "D-M", "D-F", "D-Org.", "Legal Rep", "Witness-P", "Witness-D",
         "Crim-Custody","Other Details"]
len(col_names)
# Out:
# 38

# %%
sample_data = pd.read_excel("Data/Sample Data.xlsx", names = col_names)
sample_data.head(6)
# Out:
#    empty                                    T-Day T-Month T-Year  \
# 0    NaN  Court station name: \n(Entry required.)     NaN    NaN
# 1    NaN                                      NaN     NaN    NaN
# 2    NaN               \nToday's date\n\n\n\n\n\n     NaN    NaN
# 3    NaN                                      Day   Month   Year
# 4    NaN                                        3     Apr   2023
# 5    NaN                                        3     Apr   2023
#
#                                            Code     No R-Day R-Month R-Year  \
# 0                                   A. N. Other    NaN   NaN     NaN    NaN
# 1                                           NaN    NaN   NaN     NaN    NaN
# 2  \nCase Number  and date of Registration)\n\n    NaN   NaN     NaN    NaN
# 3                                          Code    No.   Day   Month   Year
# 4                                          QRCR   E642     3     Apr   2023
# 5                                          QRCR  E1411    31     Oct   2022
#
#                                         Origin Court  ...  P-F P-Org.  \
# 0                                                NaN  ...  NaN    NaN
# 1                                                NaN  ...  NaN    NaN
# 2  \n*Appeal cases only:                         ...  ...  NaN    NaN
# 3                                      Name of Court  ...    F   Org.
# 4                                                NaN  ...  NaN      1
# 5                                                NaN  ...  NaN      1
#
#                                      D-M  D-F D-Org.  \
# 0                                    NaN  NaN    NaN
# 1                                    NaN  NaN    NaN
# 2  \nNo. of defendants/accused\n\n\n\n\n  NaN    NaN
# 3                                      M    F   Org.
# 4                                      1  NaN    NaN
# 5                                      1  NaN    NaN
#
#                                            Legal Rep  \
# 0                                                NaN
# 1                                              False
# 2  \nDo any of the parties have legal representat...
# 3                                              (Y/N)
# 4                                                 No
# 5                                                 No
#
#                                            Witness-P       Witness-D  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2  \nNo. of witnesses testified in court today\n\n\n             NaN
# 3                                    P \n(Enter No.)  D\n(Enter No.)
# 4                                                NaN             NaN
# 5                                                NaN               1
#
#                                         Crim-Custody  \
# 0                                                NaN
# 1                                                NaN
# 2  \nCriminal cases only: \nOf the accused, how m...
# 3                                        (Enter No.)
# 4                                                  1
# 5                                                  0
#
#                            Other Details
# 0                                    NaN
# 1                                    NaN
# 2  \nOther important details of the case
# 3                            (Free text)
# 4                                    NaN
# 5                                    NaN
#
# [6 rows x 38 columns]

# %%
# dropping head rows
sample_data.drop(index=[0,1,2,3], inplace=True)

# %%
sample_data.head()
# Out:
#    empty T-Day T-Month T-Year      Code     No R-Day R-Month R-Year  \
# 4    NaN     3     Apr   2023      QRCR   E642     3     Apr   2023
# 5    NaN     3     Apr   2023      QRCR  E1411    31     Oct   2022
# 6    NaN     3     Apr   2023      QRCR   E649     3     Apr   2023
# 7    NaN     3     Apr   2023      QRCR   E638     3     Apr   2023
# 8    NaN     3     Apr   2023  QRCRMISC   E109     3     Apr   2023
#
#   Origin Court  ...  P-F P-Org.  D-M  D-F D-Org. Legal Rep Witness-P  \
# 4          NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 5          NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 6          NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 7          NaN  ...  NaN      1    1  NaN    NaN        No       NaN
# 8          NaN  ...  NaN      1  NaN    2    NaN        No       NaN
#
#   Witness-D Crim-Custody Other Details
# 4       NaN            1           NaN
# 5         1            0           NaN
# 6       NaN            1           NaN
# 7       NaN            1           NaN
# 8       NaN            2           NaN
#
# [5 rows x 38 columns]

# %%
sample_data.reset_index(drop=True, inplace=True)
sample_data.columns
# Out:
# Index(['empty', 'T-Day', 'T-Month', 'T-Year', 'Code', 'No', 'R-Day', 'R-Month',
#        'R-Year', 'Origin Court', 'Origin Code', 'Origin No', 'Origin Year',
#        'Specific Case Type', 'Judge 1', 'Judge 2', 'Judge 3', 'Judge 4',
#        'Judge 5', 'Judge 6', 'Judge 7', 'Case coming for', 'Case OutCome',
#        'Reason of adjournment', 'N-Day', 'N-Month', 'N-Year', 'P-M', 'P-F',
#        'P-Org.', 'D-M', 'D-F', 'D-Org.', 'Legal Rep', 'Witness-P', 'Witness-D',
#        'Crim-Custody', 'Other Details'],
#       dtype='object')

# %%
sample_data.dtypes
# Out:
# empty                    float64
# T-Day                     object
# T-Month                   object
# T-Year                    object
# Code                      object
# No                        object
# R-Day                     object
# R-Month                   object
# R-Year                    object
# Origin Court              object
# Origin Code               object
# Origin No                 object
# Origin Year               object
# Specific Case Type        object
# Judge 1                   object
# Judge 2                   object
# Judge 3                   object
# Judge 4                   object
# Judge 5                   object
# Judge 6                   object
# Judge 7                   object
# Case coming for           object
# Case OutCome              object
# Reason of adjournment     object
# N-Day                     object
# N-Month                   object
# N-Year                    object
# P-M                       object
# P-F                       object
# P-Org.                    object
# D-M                       object
# D-F                       object
# D-Org.                    object
# Legal Rep                 object
# Witness-P                 object
# Witness-D                 object
# Crim-Custody              object
# Other Details             object
# dtype: object

# %%
# Create the column Today's Date
sample_data["Today's Date"] = sample_data["T-Day"].astype(str) + "-"+  sample_data["T-Month"] + "-" +sample_data["T-Year"].astype(str)
sample_data.head()
# Out:
#    empty T-Day T-Month T-Year      Code     No R-Day R-Month R-Year  \
# 0    NaN     3     Apr   2023      QRCR   E642     3     Apr   2023
# 1    NaN     3     Apr   2023      QRCR  E1411    31     Oct   2022
# 2    NaN     3     Apr   2023      QRCR   E649     3     Apr   2023
# 3    NaN     3     Apr   2023      QRCR   E638     3     Apr   2023
# 4    NaN     3     Apr   2023  QRCRMISC   E109     3     Apr   2023
#
#   Origin Court  ... P-Org.  D-M  D-F D-Org. Legal Rep Witness-P Witness-D  \
# 0          NaN  ...      1    1  NaN    NaN        No       NaN       NaN
# 1          NaN  ...      1    1  NaN    NaN        No       NaN         1
# 2          NaN  ...      1    1  NaN    NaN        No       NaN       NaN
# 3          NaN  ...      1    1  NaN    NaN        No       NaN       NaN
# 4          NaN  ...      1  NaN    2    NaN        No       NaN       NaN
#
#   Crim-Custody Other Details Today's Date
# 0            1           NaN   3-Apr-2023
# 1            0           NaN   3-Apr-2023
# 2            1           NaN   3-Apr-2023
# 3            1           NaN   3-Apr-2023
# 4            2           NaN   3-Apr-2023
#
# [5 rows x 39 columns]

# %%
sample_data["Today's Date"] = pd.to_datetime(sample_data["Today's Date"], format="%d-%b-%Y")

# %%
sample_data.dtypes
# Out:
# empty                           float64
# T-Day                            object
# T-Month                          object
# T-Year                           object
# Code                             object
# No                               object
# R-Day                            object
# R-Month                          object
# R-Year                           object
# Origin Court                     object
# Origin Code                      object
# Origin No                        object
# Origin Year                      object
# Specific Case Type               object
# Judge 1                          object
# Judge 2                          object
# Judge 3                          object
# Judge 4                          object
# Judge 5                          object
# Judge 6                          object
# Judge 7                          object
# Case coming for                  object
# Case OutCome                     object
# Reason of adjournment            object
# N-Day                            object
# N-Month                          object
# N-Year                           object
# P-M                              object
# P-F                              object
# P-Org.                           object
# D-M                              object
# D-F                              object
# D-Org.                           object
# Legal Rep                        object
# Witness-P                        object
# Witness-D                        object
# Crim-Custody                     object
# Other Details                    object
# Today's Date             datetime64[ns]
# dtype: object

# %%
# Move the new column to the first column
sample_data.insert(0, "Today's Date", sample_data.pop("Today's Date"))

# %%
sample_data.head()
# Out:
#   Today's Date  empty T-Day T-Month T-Year      Code     No R-Day R-Month  \
# 0   2023-04-03    NaN     3     Apr   2023      QRCR   E642     3     Apr
# 1   2023-04-03    NaN     3     Apr   2023      QRCR  E1411    31     Oct
# 2   2023-04-03    NaN     3     Apr   2023      QRCR   E649     3     Apr
# 3   2023-04-03    NaN     3     Apr   2023      QRCR   E638     3     Apr
# 4   2023-04-03    NaN     3     Apr   2023  QRCRMISC   E109     3     Apr
#
#   R-Year  ...  P-F P-Org.  D-M  D-F D-Org. Legal Rep Witness-P Witness-D  \
# 0   2023  ...  NaN      1    1  NaN    NaN        No       NaN       NaN
# 1   2022  ...  NaN      1    1  NaN    NaN        No       NaN         1
# 2   2023  ...  NaN      1    1  NaN    NaN        No       NaN       NaN
# 3   2023  ...  NaN      1    1  NaN    NaN        No       NaN       NaN
# 4   2023  ...  NaN      1  NaN    2    NaN        No       NaN       NaN
#
#   Crim-Custody Other Details
# 0            1           NaN
# 1            0           NaN
# 2            1           NaN
# 3            1           NaN
# 4            2           NaN
#
# [5 rows x 39 columns]
